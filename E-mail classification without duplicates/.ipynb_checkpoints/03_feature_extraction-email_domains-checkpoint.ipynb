# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import pickle
import seaborn as sns

# %%
with open("data/train.pkl", "rb") as file:
    X_train = pickle.load(file).reset_index()

# %% [markdown]
# Pasuje pozamieniać znaki, które dolegają do słów na puste stingi

# %%
X_train["Message"] = X_train["Message"].str.replace(",", " ")
X_train["Message"] = X_train["Message"].str.replace("\n", " ")

# %%
#help(x.str.replace)

# %%
X_train.head()
# Out:
#    index  Status                                            Message
# 0   6990       0  From fork-admin@xent.com  Tue Aug 20 22:15:08 ...
# 1  10929       1  Return-Path: <Online#3.19700.89-xNOclp13QVGIDs...
# 2  12984       0  From rssfeeds@jmason.org  Tue Sep 24 10:47:34 ...
# 3   3888       0  From exmh-users-admin@redhat.com  Thu Sep 12 1...
# 4   9491       0  From sentto-2242572-60407-1039000218-jm=jmason...

# %%
np.mean(X_train["Message"].str.split(" ").str[1].str.contains("@"))
# Out:
# np.float64(0.979223125564589)

# %%
email = X_train["Message"].str.split(" ")

# %%
email_2 = email.apply(lambda x: x[np.argmax(np.char.lower(np.array(x)) == "from") + 1])

# %%
email_2.head(30)
# Out:
# 0                                   fork-admin@xent.com
# 1                               abv-sfo-acmta2.cnet.com
# 2                                   rssfeeds@jmason.org
# 3                           exmh-users-admin@redhat.com
# 4     sentto-2242572-60407-1039000218-jm=jmason.org@...
# 5                                         hq.pro-ns.net
# 6                          rpm-list-admin@freshrpms.net
# 7                                   rssfeeds@jmason.org
# 8                                   fork-admin@xent.com
# 9                                   fork-admin@xent.com
# 10                                  fork-admin@xent.com
# 11       spamassassin-devel-admin@lists.sourceforge.net
# 12                                                   my
# 13                                   zarco9@hotmail.com
# 14                                  fork-admin@xent.com
# 15                             iqsoftware@export2000.ro
# 16                         rpm-list-admin@freshrpms.net
# 17                 DVD-09242002-HTML@frugaljoe.330w.com
# 18                                                karls
# 19                                  fork-admin@xent.com
# 20                        spam-request@zorch.sf-bay.org
# 21                                  fork-admin@xent.com
# 22                         rpm-list-admin@freshrpms.net
# 23    OWNER-NOLIST-SGODAILY*JM**NETNOTEINC*-COM@SMTP...
# 24                                       pudge@perl.org
# 25              razor-users-admin@lists.sourceforge.net
# 26                                  fork-admin@xent.com
# 27              razor-users-admin@lists.sourceforge.net
# 28                                      jos_ed@mail.com
# 29              razor-users-admin@lists.sourceforge.net
# Name: Message, dtype: object

# %%
email_2.tail(30)
# Out:
# 8826                              irregulars-admin@tb.tf
# 8827                                 fork-admin@xent.com
# 8828                                       anders@hmi.de
# 8829                            sej3451840n22@excite.com
# 8830                       noonelists8387@eudoramail.com
# 8831                                 fork-admin@xent.com
# 8832                         hok_stein6877@Flashmail.com
# 8833                                 fork-admin@xent.com
# 8834                                 fork-admin@xent.com
# 8835                                 fork-admin@xent.com
# 8836    spamassassin-commits-admin@lists.sourceforge.net
# 8837                                 rssfeeds@jmason.org
# 8838                                 fork-admin@xent.com
# 8839                                 fork-admin@xent.com
# 8840                                 rssfeeds@jmason.org
# 8841                        rpm-list-admin@freshrpms.net
# 8842                                    barry@python.org
# 8843                                 fork-admin@xent.com
# 8844                                 rssfeeds@jmason.org
# 8845                                 fork-admin@xent.com
# 8846                                  dscfahy@eircom.net
# 8847                             msathene@netvigator.com
# 8848                        rpm-list-admin@freshrpms.net
# 8849                         qtopic+admin@quicktopic.com
# 8850             razor-users-admin@lists.sourceforge.net
# 8851                                           localhost
# 8852                  0xdeadbeef-request@petting-zoo.net
# 8853                                       nas@python.ca
# 8854                                 fork-admin@xent.com
# 8855                                 fork-admin@xent.com
# Name: Message, dtype: object

# %%
temp = email_2.str.split("@")

# %%
email_2 = pd.DataFrame(email_2)

# %%
email_2
# Out:
#                                                 Message
# 0                                   fork-admin@xent.com
# 1                               abv-sfo-acmta2.cnet.com
# 2                                   rssfeeds@jmason.org
# 3                           exmh-users-admin@redhat.com
# 4     sentto-2242572-60407-1039000218-jm=jmason.org@...
# ...                                                 ...
# 8851                                          localhost
# 8852                 0xdeadbeef-request@petting-zoo.net
# 8853                                      nas@python.ca
# 8854                                fork-admin@xent.com
# 8855                                fork-admin@xent.com
#
# [8856 rows x 1 columns]

# %%
email_2["part_1"] = temp.str[0]

# %%
email_2["domain"] = temp.str[1]

# %%
email_2 = pd.concat([X_train["Status"], email_2], axis=1)

# %%
email_2.head(30)
# Out:
#     Status                                            Message  \
# 0        0                                fork-admin@xent.com
# 1        1                            abv-sfo-acmta2.cnet.com
# 2        0                                rssfeeds@jmason.org
# 3        0                        exmh-users-admin@redhat.com
# 4        0  sentto-2242572-60407-1039000218-jm=jmason.org@...
# 5        2                                      hq.pro-ns.net
# 6        0                       rpm-list-admin@freshrpms.net
# 7        0                                rssfeeds@jmason.org
# 8        0                                fork-admin@xent.com
# 9        0                                fork-admin@xent.com
# 10       0                                fork-admin@xent.com
# 11       0     spamassassin-devel-admin@lists.sourceforge.net
# 12       0                                                 my
# 13       2                                 zarco9@hotmail.com
# 14       2                                fork-admin@xent.com
# 15       2                           iqsoftware@export2000.ro
# 16       0                       rpm-list-admin@freshrpms.net
# 17       2               DVD-09242002-HTML@frugaljoe.330w.com
# 18       2                                              karls
# 19       0                                fork-admin@xent.com
# 20       1                      spam-request@zorch.sf-bay.org
# 21       0                                fork-admin@xent.com
# 22       0                       rpm-list-admin@freshrpms.net
# 23       2  OWNER-NOLIST-SGODAILY*JM**NETNOTEINC*-COM@SMTP...
# 24       0                                     pudge@perl.org
# 25       0            razor-users-admin@lists.sourceforge.net
# 26       0                                fork-admin@xent.com
# 27       0            razor-users-admin@lists.sourceforge.net
# 28       2                                    jos_ed@mail.com
# 29       0            razor-users-admin@lists.sourceforge.net
#
#                                            part_1                    domain
# 0                                      fork-admin                  xent.com
# 1                         abv-sfo-acmta2.cnet.com                       NaN
# 2                                        rssfeeds                jmason.org
# 3                                exmh-users-admin                redhat.com
# 4   sentto-2242572-60407-1039000218-jm=jmason.org  returns.groups.yahoo.com
# 5                                   hq.pro-ns.net                       NaN
# 6                                  rpm-list-admin             freshrpms.net
# 7                                        rssfeeds                jmason.org
# 8                                      fork-admin                  xent.com
# 9                                      fork-admin                  xent.com
# 10                                     fork-admin                  xent.com
# 11                       spamassassin-devel-admin     lists.sourceforge.net
# 12                                             my                       NaN
# 13                                         zarco9               hotmail.com
# 14                                     fork-admin                  xent.com
# 15                                     iqsoftware             export2000.ro
# 16                                 rpm-list-admin             freshrpms.net
# 17                              DVD-09242002-HTML        frugaljoe.330w.com
# 18                                          karls                       NaN
# 19                                     fork-admin                  xent.com
# 20                                   spam-request          zorch.sf-bay.org
# 21                                     fork-admin                  xent.com
# 22                                 rpm-list-admin             freshrpms.net
# 23      OWNER-NOLIST-SGODAILY*JM**NETNOTEINC*-COM       SMTP1.ADMANMAIL.COM
# 24                                          pudge                  perl.org
# 25                              razor-users-admin     lists.sourceforge.net
# 26                                     fork-admin                  xent.com
# 27                              razor-users-admin     lists.sourceforge.net
# 28                                         jos_ed                  mail.com
# 29                              razor-users-admin     lists.sourceforge.net

# %%
important_domains = email_2["domain"].value_counts()
important_domains = important_domains[important_domains > 100]#0.01*X_train.shape[0]]

# %%
important_domains.shape
# Out:
# (10,)

# %%
pd.DataFrame(important_domains).reset_index()
# Out:
#                      domain  count
# 0                  xent.com   2174
# 1                jmason.org   1419
# 2     lists.sourceforge.net    788
# 3             freshrpms.net    669
# 4                  linux.ie    590
# 5                redhat.com    485
# 6               hotmail.com    143
# 7                  perl.org    142
# 8                 yahoo.com    122
# 9  returns.groups.yahoo.com    101

# %%
email_2 = email_2.merge(pd.DataFrame(important_domains).reset_index(),how="left", left_on="domain", right_on="domain")

# %%
email_2["Important_domain"] = np.where(~email_2["count"].isna(), email_2["domain"], "No_important")

# %%
email_2.head()
# Out:
#    Status                                            Message  \
# 0       0                                fork-admin@xent.com
# 1       1                            abv-sfo-acmta2.cnet.com
# 2       0                                rssfeeds@jmason.org
# 3       0                        exmh-users-admin@redhat.com
# 4       0  sentto-2242572-60407-1039000218-jm=jmason.org@...
#
#                                           part_1                    domain  \
# 0                                     fork-admin                  xent.com
# 1                        abv-sfo-acmta2.cnet.com                       NaN
# 2                                       rssfeeds                jmason.org
# 3                               exmh-users-admin                redhat.com
# 4  sentto-2242572-60407-1039000218-jm=jmason.org  returns.groups.yahoo.com
#
#     count          Important_domain
# 0  2174.0                  xent.com
# 1     NaN              No_important
# 2  1419.0                jmason.org
# 3   485.0                redhat.com
# 4   101.0  returns.groups.yahoo.com

# %%
email_2.isna().mean()
# Out:
# Status              0.000000
# Message             0.000000
# part_1              0.000000
# domain              0.059508
# count               0.251016
# Important_domain    0.000000
# dtype: float64

# %%
plt.figure(figsize=(30, 5))
sns.histplot(data=email_2, x="Important_domain", hue="Status", multiple="dodge", stat="probability")
plt.grid("on")
plt.show()

# %%
counted = email_2.groupby(["Important_domain","Status"]).size().reset_index(name="count")

# %%
counted.head()
# Out:
#   Important_domain  Status  count
# 0     No_important       0    531
# 1     No_important       1    340
# 2     No_important       2   1352
# 3    freshrpms.net       0    666
# 4    freshrpms.net       1      3

# %%
domains = counted.groupby("Important_domain")["count"].sum().reset_index(name="sum").merge(counted, how="right", on="Important_domain")

# %%
domains["count"] = domains["count"] / domains["sum"]

# %%
plt.figure(figsize=(30, 5))
sns.barplot(data=domains, x="Important_domain", hue="Status", y="count", palette=["green", "darkblue", "red"])
plt.grid("on")
plt.show()

# %% [markdown]
# Widzimy, że istotnie domena może mieć ogromne znaczenie, sprawdźmy dla większego zakresu domen

# %%
email_2.head()
# Out:
#    Status                                            Message  \
# 0       0                                fork-admin@xent.com
# 1       1                            abv-sfo-acmta2.cnet.com
# 2       0                                rssfeeds@jmason.org
# 3       0                        exmh-users-admin@redhat.com
# 4       0  sentto-2242572-60407-1039000218-jm=jmason.org@...
#
#                                           part_1                    domain  \
# 0                                     fork-admin                  xent.com
# 1                        abv-sfo-acmta2.cnet.com                       NaN
# 2                                       rssfeeds                jmason.org
# 3                               exmh-users-admin                redhat.com
# 4  sentto-2242572-60407-1039000218-jm=jmason.org  returns.groups.yahoo.com
#
#     count          Important_domain
# 0  2174.0                  xent.com
# 1     NaN              No_important
# 2  1419.0                jmason.org
# 3   485.0                redhat.com
# 4   101.0  returns.groups.yahoo.com

# %%
email_2["domain"].isna().mean()
# Out:
# np.float64(0.059507678410117434)

# %%
email_2["domain"] = np.where(email_2["domain"].isna(), "unknown", email_2["domain"])

# %%
threshold = 10
important_domains = email_2["domain"].value_counts()
important_domains = important_domains[important_domains > threshold]#0.01*X_train.shape[0]]

# %%
#important_domains, important_domains.shape

# %%
email_2 = email_2.merge(pd.DataFrame(important_domains).reset_index(),how="left", left_on="domain", right_on="domain")

# %%
email_2.drop(["count_x", "count_y"], axis=1, inplace=True)

# %%
email_2.head()
# Out:
#    Status                                            Message  \
# 0       0                                fork-admin@xent.com
# 1       1                            abv-sfo-acmta2.cnet.com
# 2       0                                rssfeeds@jmason.org
# 3       0                        exmh-users-admin@redhat.com
# 4       0  sentto-2242572-60407-1039000218-jm=jmason.org@...
#
#                                           part_1                    domain  \
# 0                                     fork-admin                  xent.com
# 1                        abv-sfo-acmta2.cnet.com                   unknown
# 2                                       rssfeeds                jmason.org
# 3                               exmh-users-admin                redhat.com
# 4  sentto-2242572-60407-1039000218-jm=jmason.org  returns.groups.yahoo.com
#
#            Important_domain
# 0                  xent.com
# 1                   unknown
# 2                jmason.org
# 3                redhat.com
# 4  returns.groups.yahoo.com

# %%
email_2 = email_2.merge(pd.DataFrame(important_domains).reset_index(),how="left", left_on="domain", right_on="domain")

# %%
email_2.head()
# Out:
#    Status                                            Message  \
# 0       0                                fork-admin@xent.com
# 1       1                            abv-sfo-acmta2.cnet.com
# 2       0                                rssfeeds@jmason.org
# 3       0                        exmh-users-admin@redhat.com
# 4       0  sentto-2242572-60407-1039000218-jm=jmason.org@...
#
#                                           part_1                    domain  \
# 0                                     fork-admin                  xent.com
# 1                        abv-sfo-acmta2.cnet.com                   unknown
# 2                                       rssfeeds                jmason.org
# 3                               exmh-users-admin                redhat.com
# 4  sentto-2242572-60407-1039000218-jm=jmason.org  returns.groups.yahoo.com
#
#            Important_domain   count
# 0                  xent.com  2174.0
# 1                   unknown   527.0
# 2                jmason.org  1419.0
# 3                redhat.com   485.0
# 4  returns.groups.yahoo.com   101.0

# %%
email_2["Important_domain"] = np.where(~email_2["count"].isna(), email_2["domain"], "No_important")

# %%
email_2.isna().mean()
# Out:
# Status              0.00000
# Message             0.00000
# part_1              0.00000
# domain              0.00000
# Important_domain    0.00000
# count               0.11687
# dtype: float64

# %%
important_domains.reset_index()["domain"][0]
# Out:
# 'xent.com'

# %%
counted = email_2.groupby(["Important_domain","Status"]).size().reset_index(name="count")
domains = counted.groupby("Important_domain")["count"].sum().reset_index(name="sum").merge(counted, how="right", on="Important_domain")
domains["count"] = domains["count"] / domains["sum"]

# %%
domains.head()
# Out:
#   Important_domain   sum  Status     count
# 0         2ubh.com    18       0  1.000000
# 1    Flashmail.com    17       2  1.000000
# 2     No_important  1035       0  0.186473
# 3     No_important  1035       1  0.068599
# 4     No_important  1035       2  0.744928

# %%
domains["Important_domain"].unique().shape
# Out:
# (41,)

# %%
plt.figure(figsize=(80, 5))
sns.barplot(data=domains, x="Important_domain", hue="Status", y="count", palette=["green", "darkblue", "red"])
plt.grid("on")
plt.show()

# %% [markdown]
# ## Wniosek 1: To czy dany email jest spamem, mocno zależy od domeny nadawcy - są takie domeny, gdzie 100% wysłanych maili to spam i odwrotnie

# %%
domains["Important_domain"].unique()
# Out:
# array(['2ubh.com', 'Flashmail.com', 'No_important', 'SMTP1.ADMANMAIL.COM',
#        'aol.com', 'btamail.net.cn', 'caramail.com', 'comcast.net',
#        'crackmice.com', 'dogma.slashnull.org', 'eudoramail.com',
#        'example.com', 'excite.com', 'freshrpms.net', 'hotmail.com',
#        'insiq.us', 'insurancemail.net', 'jmason.org', 'kluge.net',
#        'linux.ie', 'lists.sourceforge.net', 'mail.com',
#        'mediaunspun.imakenews.net', 'msn.com', 'netscape.net',
#        'pathname.com', 'perl.org', 'petting-zoo.net', 'pobox.com',
#        'python.org', 'redhat.com', 'returns.groups.yahoo.com',
#        'securityfocus.com', 'spamassassin.taint.org', 'srv0.ems.ed.ac.uk',
#        'taint.org', 'unknown', 'vulnwatch.org', 'xent.com', 'yahoo.co.uk',
#        'yahoo.com'], dtype=object)

# %%
important_domains.index
